# %% [markdown]
# # AUCMEDI Example
#
# ## Regular pipeline
#
# This sample notebook gives you an impression on how to apply *AUCMEDI* to any common image classification task in the field of medical imaging. We provide step-by-step explanations to help you understand, what's happening.

# %% [markdown]
# ### Step 1: Setup
#
# Setting up GPU

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# ### Step 2: Imports
#
# Besides the *AUCMEDI* library, we use `os` to manage file paths, and `csv` to handle CSV files. To add callbacks to our model, we also work with `tensorflow` directly. For XAI in step 18, we need to be able to generate some simple random numbers, using `random`. We're storing our XAI related predictions using `pandas`.

# %%
from aucmedi import *
import csv
import tensorflow as tf
import random
import pandas as pd

# %% [markdown]
# ***
#
# ### Step 3: Constants
#
# For convenience, we define the constant values we need along the way here.

# %%
# Seed for replicability of random actions
seed = 341

# Is the classification task a multi-label problem?
is_multilabel = True
activation_function = 'sigmoid' if is_multilabel else 'softmax'

# CSV: Are the labels one-hot-encoded?
is_ohe = True

# Epochs to train
epochs = 500

# Splits
splits = [0.7, 0.1, 0.2]

# Label that impacts the output path
iteration_index = '08'
project_name = 'riadd'
iteration_label = '{}_{}'.format(iteration_index, project_name)

# Interface type
type_of_annotations = 'csv'

# CSV: Identifying column within our interface
col_id = 'ID'
csv_newline = ''

# Paths
path_input = os.path.join('assets', 'sample', project_name, 'Training')
path_snapshot = os.path.join('assets', iteration_label, 'out', 'snapshots')
path_snapshot_file = os.path.join('assets', iteration_label, 'out', 'snapshots', 'model.h5')
path_history = os.path.join('assets', iteration_label, 'out', 'history')
path_images = os.path.join('assets', iteration_label, 'out', 'img')
path_class_distribution = os.path.join('assets', iteration_label, 'info')
path_xai = os.path.join('assets', iteration_label, 'out', 'xai')
path_xai_predictions = os.path.join(path_xai, 'predictions.csv')

# CSV: Path to ground truth
path_truth = os.path.join('assets', 'sample', project_name, 'RFMiD_Training_Labels.csv')

# Model specifics
architecture_name = '2D.DenseNet121'
nn_metrics = ['categorical_accuracy']
use_pretrained = True
callbacks = []

# %% [markdown]
# ***
#
# ### Step 4: Create output directories
#
# To avoid mistakes, we want to make sure that the training-specific output paths are generated anew.

# %%
os.makedirs(path_snapshot, exist_ok=False)
os.makedirs(path_images, exist_ok=False)
os.makedirs(path_class_distribution, exist_ok=False)

# %% [markdown]
# ***
#
# ### Step 5: Read ground truth
#
# To find all available classes, we need to distinguish if we have a `CSV` based annotation or if we're using directories.
#
# #### Step 5.1: CSV
#
# With a CSV-based interface, we can read the labels from the ground truth file.
#
# #### Step 5.2: Directory
#
# When using directories, we simply need to read the labels of all sub-directories.

# %%
valid_classes = None

def handle_csv():
    with open(path_truth, newline=csv_newline) as file:
        reader = csv.reader(file)
        first_row = next(reader)
        
        # Since the ISIC training data set does not contain any samples for 'UNK', we eliminate the class for our purposes
        if project_name == 'dermatoscopy': 
            return [th for th in first_row if th != col_id and th != 'UNK']
        else: 
            return first_row[1:]

annotation_handler = {
    'csv': handle_csv
}

try:
    valid_classes = annotation_handler[type_of_annotations]()
    print('Valid classes have been successfully set!')
    print(valid_classes)
except KeyError:
    print('Cannot handle annotation type {}'.format(type_of_annotations))
# Out:
# Valid classes have been successfully set!
# ['Disease_Risk', 'DR', 'ARMD', 'MH', 'DN', 'MYA', 'BRVO', 'TSLN', 'ERM', 'LS', 'MS', 'CSR', 'ODC', 'CRVO', 'TV', 'AH', 'ODP', 'ODE', 'ST', 'AION', 'PT', 'RT', 'RS', 'CRS', 'EDN', 'RPEC', 'MHL', 'RP', 'OTHER']

# %% [markdown]
# ***
#
# ### Step 6: Load data
#
# By calling `input_interface()`, we can load all the information we need about a data set.

# %%
if type_of_annotations == 'csv':
    ds_loader = input_interface(
        interface=type_of_annotations, # Type of annotations
        path_imagedir=path_input, # Path to images
        col_sample=col_id, # Name of the column that identifies an image
        path_data=path_truth, # Path to labels
        ohe=is_ohe, # Are labels one-hot-encoded?
        ohe_range=valid_classes # Possible values
    )
elif type_of_annotations == 'directory':
    ds_loader = input_interface(
        interface=type_of_annotations,
        path_imagedir=path_input
    )

(index_list, labels_ohe, n_classes, class_names, image_format) = ds_loader

# %% [markdown]
# ***
#
# ### Step 7: Class distribution
#
# To plot the class distribution, we can use *AUCMEDI*'s [evaluate functionality](https://frankkramer-lab.github.io/aucmedi/reference/evaluation/dataset/#aucmedi.evaluation.dataset.evaluate_dataset).

# %%
from aucmedi.evaluation import *

evaluate_dataset(
    samples=index_list,
    labels=labels_ohe,
    out_path=path_class_distribution,
    class_names=class_names,
    plot_barplot=True
)
# Out:
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 10 x 9 in image.
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: assets/08_riadd/info/plot.dataset.barplot.png
#            class class_freq  class_perc
# 0   Disease_Risk       1519        79.0
# 1             DR        376        20.0
# 2           ARMD        100         5.0
# 3             MH        317        17.0
# 4             DN        138         7.0
# 5            MYA        101         5.0
# 6           BRVO         73         4.0
# 7           TSLN        186        10.0
# 8            ERM         14         1.0
# 9             LS         47         2.0
# 10            MS         15         1.0
# 11           CSR         37         2.0
# 12           ODC        282        15.0
# 13          CRVO         28         1.0
# 14            TV          6         0.0
# 15            AH         16         1.0
# 16           ODP         65         3.0
# 17           ODE         58         3.0
# 18            ST          5         0.0
# 19          AION         17         1.0
# 20            PT         11         1.0
# 21            RT         14         1.0
# 22            RS         43         2.0
# 23           CRS         32         2.0
# 24           EDN         15         1.0
# 25          RPEC         22         1.0
# 26           MHL         11         1.0
# 27            RP          6         0.0
# 28         OTHER         34         2.0

# %% [markdown]
# ***
#
# ### Step 8: Split data set
#
# For our case, we are splitting our set of images into three data sets, `set_train`, `set_val` and `set_test` respectively.

# %%
from aucmedi.sampling.split import sampling_split

set_train, set_val, set_test = sampling_split(
    samples=index_list, # list of sample names
    labels=labels_ohe, # list of corresponding labels
    sampling=splits, # percentage splits
    stratified=True, # Allow overlaps between sets
    iterative=is_multilabel, # Approximation of a solution is only useful for multi label problems
    seed=seed # Seed for replicability of random actions
)

# %% [markdown]
# ***
#
# ### Step 9: Prepare model
#
# In preparation for a robust classificator, we plan on using common utilities, like image augmentation and several callbacks.
#
# #### 9.1: Image Augmentation
#
# By default, the `Image_Augmentation` object applies
#
# - Flipping
# - Rotation
# - Changes to brightness
# - Changes to contrast
# - Changes to saturation
# - Changes to hue
# - Changes to scale

# %%
from aucmedi.data_processing import augmentation

data_aug = augmentation.ImageAugmentation()

# %% [markdown]
# ***
#
# #### 9.2 Callback: Early Stopping
#
# When we see none, or very small improvements in performance, we abort training to save resources.
#
# #### 9.3: Callback: Dynamic Learning Rate
#
# Reducing the learning rate, is often beneficial to models, when improvements are beginning to stagnate.
#
# #### 9.4: Callback: CSV Logger
#
# We intend to persist the histories that our training generates for further analysis.
#
# #### 9.5: Callback: Checkpoint
#
# To persist our model, we use the callback ModelCheckpoint.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, CSVLogger, ModelCheckpoint

# 9.2 Early Stopping
cb_early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=12,
    verbose=1,
)

callbacks.append(cb_early_stopping)

# 9.3 Dynamic learning rate
cb_reduce_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    verbose=1,
    mode='min',
    min_lr=1e-7
)

callbacks.append(cb_reduce_learning_rate)

# 9.4 CSV Logger
cb_csv_logger = CSVLogger(
    filename=path_history,
    separator=',',
    append=True
)

callbacks.append(cb_csv_logger)

# 9.5 Model Checkpoint
cb_model_checkpoint = ModelCheckpoint(
    filepath=path_snapshot_file,
    monitor='val_loss',
    save_best_only=True
)

callbacks.append(cb_model_checkpoint)

# %% [markdown]
# ***
#
# ### Step 10: Model
#
# Before we can build our model, we need to instantiate the class weights and loss function. Please note: Multilabel problems have to be handled explicitly, because their classes potentially overlap.

# %%
from aucmedi.utils.class_weights import compute_class_weights, compute_multilabel_weights
from aucmedi.neural_network.loss_functions import *
from aucmedi.neural_network import model

# Loss
if is_multilabel:
    class_weights = compute_multilabel_weights(set_train[1])
    loss = multilabel_focal_loss(class_weights)
else: 
    cw_loss, class_weights = compute_class_weights(set_train[1])
    loss = categorical_focal_loss(cw_loss)

model = model.NeuralNetwork(
    n_labels=n_classes,
    channels=3,
    architecture=architecture_name,
    pretrained_weights=use_pretrained,
    loss=loss, # Categorical focal loss for both multiclass and binary problems
    metrics=nn_metrics,
    activation_output=activation_function # Sigmoid for multilabel problems, else softmax
)
# Out:
# 2022-09-12 12:22:59.551334: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-12 12:23:00.108942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22846 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:3f:00.0, compute capability: 7.5

# %% [markdown]
# ***
#
# ### Step 11: Prepare training
#
# Training the model with our `training` and `validation` sets, requires an instance of a `DataGenerator`, each.

# %%
from aucmedi.data_processing import data_generator

gen_train = data_generator.DataGenerator(
    samples=set_train[0],
    labels=set_train[1],
    path_imagedir=path_input,
    image_format=image_format,
    data_aug=data_aug,
    resize=model.meta_input, # Applying transfer learning, means that we should not change the model's image size expectations
    standardize_mode=model.meta_standardize, # Same goes for the standardization of values
    seed=seed
)

gen_val = data_generator.DataGenerator(
    samples=set_val[0],
    labels=set_val[1],
    path_imagedir=path_input,
    image_format=image_format,
    data_aug=data_aug,
    resize=model.meta_input, # Applying transfer learning, means that we should not change the model's image size expectations
    standardize_mode=model.meta_standardize, # Same goes for the standardization of values
    seed=seed
)

# %% [markdown]
# ***
#
# ### Step 12: Training
#
# To train a model, we provide the `train()` function with our callbacks and the training and validation generator.

# %%
history = model.train(
    training_generator=gen_train,
    validation_generator=gen_val,
    epochs=epochs,
    callbacks=callbacks,
    # class_weights=class_weights, # Applying class weights is incompatible with the focal loss function we define in step 10. 
    transfer_learning=True
)
# Out:
# Epoch 1/10
# 2022-09-12 12:23:12.412070: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# 2022-09-12 12:23:12.932031: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 42/42 [==============================] - 184s 4s/step - loss: 13.8251 - categorical_accuracy: 0.3378 - val_loss: 2.5256 - val_categorical_accuracy: 0.9010 - lr: 1.0000e-04
# Epoch 2/10
# 42/42 [==============================] - 168s 4s/step - loss: 3.0005 - categorical_accuracy: 0.7753 - val_loss: 2.3579 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 3/10
# 42/42 [==============================] - 166s 4s/step - loss: 2.7950 - categorical_accuracy: 0.7865 - val_loss: 2.4704 - val_categorical_accuracy: 0.9896 - lr: 1.0000e-04
# Epoch 4/10
# 42/42 [==============================] - 169s 4s/step - loss: 2.8076 - categorical_accuracy: 0.8177 - val_loss: 2.3381 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 5/10
# 42/42 [==============================] - 165s 4s/step - loss: 2.8040 - categorical_accuracy: 0.7991 - val_loss: 2.4109 - val_categorical_accuracy: 0.9948 - lr: 1.0000e-04
# Epoch 6/10
# 42/42 [==============================] - 162s 4s/step - loss: 2.7310 - categorical_accuracy: 0.8371 - val_loss: 2.3624 - val_categorical_accuracy: 0.9948 - lr: 1.0000e-04
# Epoch 7/10
# 42/42 [==============================] - 165s 4s/step - loss: 2.6012 - categorical_accuracy: 0.8125 - val_loss: 2.3649 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 8/10
# 42/42 [==============================] - 166s 4s/step - loss: 2.6272 - categorical_accuracy: 0.8371 - val_loss: 2.3807 - val_categorical_accuracy: 0.9948 - lr: 1.0000e-04
# Epoch 9/10
# 42/42 [==============================] - 165s 4s/step - loss: 2.5417 - categorical_accuracy: 0.8438 - val_loss: 2.3354 - val_categorical_accuracy: 0.9948 - lr: 1.0000e-04
# Epoch 10/10
# 42/42 [==============================] - 169s 4s/step - loss: 2.5233 - categorical_accuracy: 0.8304 - val_loss: 2.2401 - val_categorical_accuracy: 0.9896 - lr: 1.0000e-04
# Epoch 11/500
# 42/42 [==============================] - 177s 4s/step - loss: 2.7582 - categorical_accuracy: 0.8936 - val_loss: 2.2777 - val_categorical_accuracy: 0.9948 - lr: 1.0000e-05
# Epoch 12/500
# 42/42 [==============================] - 165s 4s/step - loss: 2.6278 - categorical_accuracy: 0.9062 - val_loss: 2.2384 - val_categorical_accuracy: 0.9896 - lr: 1.0000e-05
# Epoch 13/500
# 42/42 [==============================] - 164s 4s/step - loss: 2.5828 - categorical_accuracy: 0.8943 - val_loss: 2.3320 - val_categorical_accuracy: 0.9844 - lr: 1.0000e-05
# Epoch 14/500
# 42/42 [==============================] - 162s 4s/step - loss: 2.4410 - categorical_accuracy: 0.8772 - val_loss: 2.2859 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-05
# Epoch 15/500
# 42/42 [==============================] - 167s 4s/step - loss: 2.4689 - categorical_accuracy: 0.8445 - val_loss: 2.2358 - val_categorical_accuracy: 0.9792 - lr: 1.0000e-05
# Epoch 16/500
# 42/42 [==============================] - 167s 4s/step - loss: 2.3632 - categorical_accuracy: 0.8676 - val_loss: 2.2193 - val_categorical_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 17/500
# 42/42 [==============================] - 164s 4s/step - loss: 2.3802 - categorical_accuracy: 0.8519 - val_loss: 2.2970 - val_categorical_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 18/500
# 42/42 [==============================] - 166s 4s/step - loss: 2.3458 - categorical_accuracy: 0.8378 - val_loss: 2.1534 - val_categorical_accuracy: 0.9635 - lr: 1.0000e-05
# Epoch 19/500
# 42/42 [==============================] - 165s 4s/step - loss: 2.2861 - categorical_accuracy: 0.8281 - val_loss: 2.2066 - val_categorical_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 20/500
# 42/42 [==============================] - 165s 4s/step - loss: 2.2802 - categorical_accuracy: 0.8430 - val_loss: 2.2088 - val_categorical_accuracy: 0.9844 - lr: 1.0000e-05
# Epoch 21/500
# 42/42 [==============================] - 164s 4s/step - loss: 2.2260 - categorical_accuracy: 0.8006 - val_loss: 2.2412 - val_categorical_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 22/500
# 42/42 [==============================] - 168s 4s/step - loss: 2.1697 - categorical_accuracy: 0.8162 - val_loss: 2.1300 - val_categorical_accuracy: 0.9635 - lr: 1.0000e-05
# Epoch 23/500
# 42/42 [==============================] - 167s 4s/step - loss: 2.1614 - categorical_accuracy: 0.8155 - val_loss: 2.0040 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-05
# Epoch 24/500
# 42/42 [==============================] - 164s 4s/step - loss: 2.0968 - categorical_accuracy: 0.8207 - val_loss: 2.0941 - val_categorical_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 25/500
# 42/42 [==============================] - 166s 4s/step - loss: 2.1153 - categorical_accuracy: 0.8266 - val_loss: 2.0995 - val_categorical_accuracy: 0.9479 - lr: 1.0000e-05
# Epoch 26/500
# 42/42 [==============================] - 166s 4s/step - loss: 2.0922 - categorical_accuracy: 0.8125 - val_loss: 2.1560 - val_categorical_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 27/500
# 42/42 [==============================] - 165s 4s/step - loss: 2.0911 - categorical_accuracy: 0.8199 - val_loss: 1.9178 - val_categorical_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 28/500
# 42/42 [==============================] - 165s 4s/step - loss: 2.0154 - categorical_accuracy: 0.8058 - val_loss: 2.0742 - val_categorical_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 29/500
# 42/42 [==============================] - 166s 4s/step - loss: 1.9554 - categorical_accuracy: 0.8103 - val_loss: 2.1176 - val_categorical_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 30/500
# 42/42 [==============================] - 166s 4s/step - loss: 1.9404 - categorical_accuracy: 0.8192 - val_loss: 2.0478 - val_categorical_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 31/500
# 42/42 [==============================] - 162s 4s/step - loss: 1.8945 - categorical_accuracy: 0.7932 - val_loss: 2.0648 - val_categorical_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 32/500
# 42/42 [==============================] - ETA: 0s - loss: 1.8793 - categorical_accuracy: 0.8207
# Epoch 32: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 42/42 [==============================] - 165s 4s/step - loss: 1.8793 - categorical_accuracy: 0.8207 - val_loss: 1.9640 - val_categorical_accuracy: 0.9479 - lr: 1.0000e-05
# Epoch 33/500
# 42/42 [==============================] - 165s 4s/step - loss: 1.8749 - categorical_accuracy: 0.8118 - val_loss: 1.9190 - val_categorical_accuracy: 0.9479 - lr: 1.0000e-06
# Epoch 34/500
# 42/42 [==============================] - 168s 4s/step - loss: 1.8831 - categorical_accuracy: 0.8095 - val_loss: 1.9924 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-06
# Epoch 35/500
# 42/42 [==============================] - 165s 4s/step - loss: 1.8996 - categorical_accuracy: 0.8095 - val_loss: 1.9111 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-06
# Epoch 36/500
# 42/42 [==============================] - 166s 4s/step - loss: 1.8272 - categorical_accuracy: 0.8080 - val_loss: 1.9860 - val_categorical_accuracy: 0.9375 - lr: 1.0000e-06
# Epoch 37/500
# 42/42 [==============================] - 169s 4s/step - loss: 1.7979 - categorical_accuracy: 0.7954 - val_loss: 2.0179 - val_categorical_accuracy: 0.9375 - lr: 1.0000e-06
# Epoch 38/500
# 42/42 [==============================] - 163s 4s/step - loss: 1.8833 - categorical_accuracy: 0.8177 - val_loss: 1.9263 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-06
# Epoch 39/500
# 42/42 [==============================] - 164s 4s/step - loss: 1.9095 - categorical_accuracy: 0.8274 - val_loss: 2.0570 - val_categorical_accuracy: 0.9271 - lr: 1.0000e-06
# Epoch 40/500
# 42/42 [==============================] - 164s 4s/step - loss: 1.8547 - categorical_accuracy: 0.8110 - val_loss: 1.9082 - val_categorical_accuracy: 0.9479 - lr: 1.0000e-06
# Epoch 41/500
# 42/42 [==============================] - 166s 4s/step - loss: 1.9175 - categorical_accuracy: 0.8170 - val_loss: 1.9701 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-06
# Epoch 42/500
# 42/42 [==============================] - 166s 4s/step - loss: 1.8758 - categorical_accuracy: 0.7924 - val_loss: 1.9595 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-06
# Epoch 43/500
# 42/42 [==============================] - 167s 4s/step - loss: 1.8565 - categorical_accuracy: 0.8192 - val_loss: 1.9709 - val_categorical_accuracy: 0.9479 - lr: 1.0000e-06
# Epoch 44/500
# 42/42 [==============================] - 165s 4s/step - loss: 1.8396 - categorical_accuracy: 0.8118 - val_loss: 2.0162 - val_categorical_accuracy: 0.9167 - lr: 1.0000e-06
# Epoch 45/500
# 42/42 [==============================] - ETA: 0s - loss: 1.8900 - categorical_accuracy: 0.8177
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1e-07.
# 42/42 [==============================] - 165s 4s/step - loss: 1.8900 - categorical_accuracy: 0.8177 - val_loss: 2.0478 - val_categorical_accuracy: 0.9427 - lr: 1.0000e-06
# Epoch 46/500
# 42/42 [==============================] - 166s 4s/step - loss: 1.8431 - categorical_accuracy: 0.8140 - val_loss: 2.1011 - val_categorical_accuracy: 0.9427 - lr: 1.0000e-07
# Epoch 47/500
# 42/42 [==============================] - 164s 4s/step - loss: 1.7826 - categorical_accuracy: 0.8199 - val_loss: 1.9638 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-07
# Epoch 48/500
# 42/42 [==============================] - 165s 4s/step - loss: 1.8274 - categorical_accuracy: 0.7932 - val_loss: 1.9916 - val_categorical_accuracy: 0.9427 - lr: 1.0000e-07
# Epoch 49/500
# 42/42 [==============================] - 163s 4s/step - loss: 1.9080 - categorical_accuracy: 0.8051 - val_loss: 1.8944 - val_categorical_accuracy: 0.9375 - lr: 1.0000e-07
# Epoch 50/500
# 42/42 [==============================] - 161s 4s/step - loss: 1.8223 - categorical_accuracy: 0.8080 - val_loss: 1.9720 - val_categorical_accuracy: 0.9635 - lr: 1.0000e-07
# Epoch 51/500
# 42/42 [==============================] - 167s 4s/step - loss: 1.8406 - categorical_accuracy: 0.7976 - val_loss: 1.9286 - val_categorical_accuracy: 0.9688 - lr: 1.0000e-07
# Epoch 52/500
# 42/42 [==============================] - 166s 4s/step - loss: 1.8604 - categorical_accuracy: 0.8088 - val_loss: 2.0323 - val_categorical_accuracy: 0.9323 - lr: 1.0000e-07
# Epoch 53/500
# 42/42 [==============================] - 163s 4s/step - loss: 1.8884 - categorical_accuracy: 0.7961 - val_loss: 1.9866 - val_categorical_accuracy: 0.9583 - lr: 1.0000e-07
# Epoch 54/500
# 42/42 [==============================] - 164s 4s/step - loss: 1.8775 - categorical_accuracy: 0.8296 - val_loss: 1.9679 - val_categorical_accuracy: 0.9688 - lr: 1.0000e-07
# Epoch 55/500
# 42/42 [==============================] - 164s 4s/step - loss: 1.8741 - categorical_accuracy: 0.8155 - val_loss: 1.9977 - val_categorical_accuracy: 0.9479 - lr: 1.0000e-07
# Epoch 56/500
# 42/42 [==============================] - 165s 4s/step - loss: 1.8222 - categorical_accuracy: 0.8162 - val_loss: 2.0312 - val_categorical_accuracy: 0.9531 - lr: 1.0000e-07
# Epoch 57/500
# 42/42 [==============================] - 163s 4s/step - loss: 1.8402 - categorical_accuracy: 0.7984 - val_loss: 1.9423 - val_categorical_accuracy: 0.9219 - lr: 1.0000e-07
# Epoch 58/500
# 42/42 [==============================] - 163s 4s/step - loss: 1.8042 - categorical_accuracy: 0.7984 - val_loss: 1.9151 - val_categorical_accuracy: 0.9688 - lr: 1.0000e-07
# Epoch 59/500
# 42/42 [==============================] - 165s 4s/step - loss: 1.8567 - categorical_accuracy: 0.8207 - val_loss: 1.9999 - val_categorical_accuracy: 0.9323 - lr: 1.0000e-07
# Epoch 60/500
# 42/42 [==============================] - 167s 4s/step - loss: 1.8552 - categorical_accuracy: 0.8088 - val_loss: 2.0390 - val_categorical_accuracy: 0.9479 - lr: 1.0000e-07
# Epoch 61/500
# 42/42 [==============================] - 163s 4s/step - loss: 1.8524 - categorical_accuracy: 0.8162 - val_loss: 1.9349 - val_categorical_accuracy: 0.9427 - lr: 1.0000e-07
# Epoch 61: early stopping

# %% [markdown]
# ***
#
# ### Step 13: Prepare prediction
#
# Similar to our training preparations, we also need to create a `DataGenerator` for predicting labels for our test set.

# %%
gen_test = data_generator.DataGenerator(
    samples=set_test[0],
    labels=None,
    path_imagedir=path_input,
    image_format=image_format,
    data_aug=None, # Cannot manipulate testing images
    resize=model.meta_input, # Applying transfer learning, means that we should not change the model's image size expectations
    standardize_mode=model.meta_standardize, # Same goes for the standardization of values
    seed=seed
)

# %% [markdown]
# ***
#
# ### Step 14: Prediction
#
# Predictions can be generated with the `model.predict()` function.
# For a simple network, the function returns an array of dimensions `(n_samples, n_classes)`.

# %%
predictions = model.predict(
    prediction_generator=gen_test
)
# Out:
# 12/12 [==============================] - 42s 3s/step

# %% [markdown]
# ***
#
# ### Step 15: Evaluate fitting
#
# Let's visualize the fitting progress. We have two options here:
#
# - If we store the history, that is generated during training, we can simply call *AUCMEDI*'s `evaluate_fitting()` method.
# - If we stored the history using a `CSVLogger`, as we did in step 9.4, we can convert that into a history dictionary and use the exact same function `evaluate_fitting()`. Since the stored history contains no information about the transfer learning epochs, the vertical line is missing here.

# %%
from aucmedi import evaluation
from aucmedi.utils.callbacks import *

# Option 1: From history dictionary (in-memory)
evaluation.fitting.evaluate_fitting(
    train_history=history,
    out_path=path_images,
    suffix='from_memory',
    show=True
)

# Option 2: From CSV
loaded_history = csv_to_history(path_history)
evaluation.fitting.evaluate_fitting(
    train_history=loaded_history,
    out_path=path_images,
    suffix='from_file',
    show=True
)
# Out:
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: assets/08_riadd/out/img/plot.fitting_course.from_memory.png
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: assets/08_riadd/out/img/plot.fitting_course.from_file.png

# %% [markdown]
# ***
#
# ### Step 16: Evaluation
#
# To evaluate our model's performance, we can use *AUCMEDI*'s `evaluation` module.

# %%
from aucmedi.evaluation import metrics

scores = metrics.compute_metrics(
    preds=predictions,
    labels=set_test[1],
    n_labels=n_classes
)
# Out:
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ***
#
# ### Step 17: Visualization
#
# In order for us to actually see the scores we achieved, we'll need some charts. In the `evaluation`, *AUCMEDI* also provides methods to visualize the results.

# %%
from aucmedi.evaluation import performance

performance.evaluate_performance(
    preds=predictions,
    labels=set_test[1],
    out_path=path_images,
    class_names=class_names,
    show=True,
    multi_label=is_multilabel
)
# Out:
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:73: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/metrics.py:76: RuntimeWarning: invalid value encountered in true_divide
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/performance.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 12 x 9 in image.
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: assets/08_riadd/out/img/plot.performance.barplot.png
# /home/main/.local/lib/python3.8/site-packages/plotnine/layer.py:412: PlotnineWarning: geom_col : Removed 38 rows containing missing values.
# /home/main/.local/lib/python3.8/site-packages/plotnine/layer.py:412: PlotnineWarning: geom_col : Removed 38 rows containing missing values.
# /home/main/.local/lib/python3.8/site-packages/aucmedi/evaluation/performance.py:239: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 10 x 9 in image.
# /home/main/.local/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: assets/08_riadd/out/img/plot.performance.roc.png
#           metric       score         class
# 0             TP  237.000000  Disease_Risk
# 1             TN   49.000000  Disease_Risk
# 2             FP   37.000000  Disease_Risk
# 3             FN   61.000000  Disease_Risk
# 4    Sensitivity    0.795302  Disease_Risk
# ..           ...         ...           ...
# 372          FNR    1.000000         OTHER
# 373          FDR         NaN         OTHER
# 374     Accuracy    0.981771         OTHER
# 375           F1    0.000000         OTHER
# 376          AUC    0.716180         OTHER
#
# [377 rows x 3 columns]

# %% [markdown]
# ***
#
# ### Step 18: XAI
#
# Understanding how a trained net decides, is invaluable. *AUCMEDI* comes with XAI functions, that can provide some insights. Please note: We have to build a separate `DataGenerator` and make an isolated prediction to calculate the Gradcam visualization.

# %%
from aucmedi.xai.decoder import xai_decoder

os.makedirs(path_xai, exist_ok=True)

# Multiclass: Find sample indices for each class
def find_relevant_indices():
    indices = {}
    occurring_masks, counts = np.unique(set_test[1], axis=0, return_counts=True)

    for mask_index, mask in enumerate(occurring_masks):
        key = np.flatnonzero(mask)
        filter = [sample_index for sample_index, sample in enumerate(set_test[1]) if (sample == mask).all()]
        indices[key[0]] = filter
    return indices

# XAI: Multilabel
def xai_multilabel():
    rdn = random.randint(0, len(set_test[1]) - 1)
    gen_xai_multilabel = data_generator.DataGenerator(
        samples=[set_test[0][rdn]], # Array containing one sample!
        labels=None,
        path_imagedir=path_input,
        image_format=image_format,
        data_aug=None,
        resize=model.meta_input,
        standardize_mode=model.meta_standardize,
        seed=seed
    )
    
    # Make and save predictions
    preds_xai_multilabel = model.predict(gen_xai_multilabel)
    columns = class_names
    preds_pd = pd.DataFrame(data=preds_xai_multilabel, columns=columns, index=[set_test[0][rdn]])
    preds_pd.to_csv(path_xai_predictions)
    
    xai_decoder(gen_xai_multilabel, model, preds=None, method="gradcam", out_path=path_xai)

# XAI: Multiclass
def xai_multiclass(): 
    relevant_indices = find_relevant_indices()
    chosen_samples = []
    for n in range(n_classes):
        if n not in relevant_indices:
            print('Could not find key {}. Must be empty.'.format(n))
        else:
            print('Found key {}! Belongs to class {}.'.format(n, class_names[n]))
            values = relevant_indices[n]
            rdn = random.randint(0, len(values) - 1)
            chosen = values[rdn]
            sample = set_test[0][chosen]
            chosen_samples.append(sample)
            
    gen_xai_multiclass = data_generator.DataGenerator(
        samples=chosen_samples,
        labels=None,
        path_imagedir=path_input,
        image_format=image_format,
        data_aug=None,
        resize=model.meta_input,
        standardize_mode=model.meta_standardize,
        seed=seed
    )
    
    # Make and save predictions
    preds_xai_multiclass = model.predict(gen_xai_multiclass)
    columns = [l for l in class_names if (project_name != 'dermatoscopy' or (project_name == 'dermatoscopy' and l != 'UNK'))]
    index = chosen_samples
    preds_pd = pd.DataFrame(data=preds_xai_multiclass, columns=columns, index=index)
    preds_pd.to_csv(path_xai_predictions)
        
    xai_decoder(gen_xai_multiclass, model, preds=preds_xai_multiclass, method="gradcam", out_path=path_xai)
    
xai_handler = {
    'multilabel': xai_multilabel,
    'multiclass': xai_multiclass
}

xai_handler['multilabel' if is_multilabel else 'multiclass']()
print('XAI images have been generated!')
# Out:
# 1/1 [==============================] - 0s 238ms/step
# XAI images have been generated!
